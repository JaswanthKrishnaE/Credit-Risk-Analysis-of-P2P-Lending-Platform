# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
df=pd.read_csv('/content/drive/MyDrive/Bondora_preprocessed.csv',low_memory=False)
df.head()
# Out:
#    Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0           0                     0        0    115.0410                  1
# 1           1                     0        0    140.6057                  0
# 2           2                     0        0    319.5580                  1
# 3           3                     0        0     57.5205                  1
# 4           4                     0        0    319.5582                  1
#
#    VerificationType LanguageCode  Age  Gender Country  AppliedAmount  \
# 0               2.0            1   61     1.0      EE       319.5582
# 1               2.0            1   48     1.0      EE       191.7349
# 2               2.0            1   58     1.0      EE       319.5582
# 3               2.0            1   23     1.0      EE       127.8233
# 4               2.0            1   25     1.0      EE       319.5582
#
#      Amount  Interest  LoanDuration  MonthlyPayment    County          City  \
# ...

# %%
df.shape
# Out:
# (134529, 43)

# %%
df.tail()
# Out:
#         Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  \
# 134524      134524                  2515        0       485.0
# 134525      134525                  1880        0      1120.0
# 134526      134526                  1975        0       525.0
# 134527      134527                  1840        0      1160.0
# 134528      134528                  2990        0        10.0
#
#         NewCreditCustomer  VerificationType LanguageCode  Age  Gender Country  \
# 134524                  1               3.0            4   37     0.0      FI
# 134525                  0               3.0            4   35     0.0      FI
# 134526                  1               1.0            4   40     0.0      FI
# 134527                  0               4.0            1   47     1.0      EE
# 134528                  0               4.0            1   21     1.0      EE
#
#         AppliedAmount  Amount  Interest  LoanDuration  MonthlyPayment  \
# ...

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#         BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0                          0        0    115.0410                  1
# 1                          0        0    140.6057                  0
# 2                          0        0    319.5580                  1
# 3                          0        0     57.5205                  1
# 4                          0        0    319.5582                  1
# ...                      ...      ...         ...                ...
# 134524                  2515        0    485.0000                  1
# 134525                  1880        0   1120.0000                  0
# 134526                  1975        0    525.0000                  1
# 134527                  1840        0   1160.0000                  0
# 134528                  2990        0     10.0000                  0
#
#         VerificationType LanguageCode  Age  Gender Country  AppliedAmount  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  BidsPortfolioManager        BidsApi     BidsManual  \
# count  134529.000000         134529.000000  134529.000000  134529.000000
# mean    67264.000000            966.452876      29.111664     559.332590
# std     38835.321519           1355.686016     150.159148     750.360512
# min         0.000000              0.000000       0.000000       0.000000
# 25%     33632.000000            155.000000       0.000000      96.000000
# 50%     67264.000000            465.000000       0.000000     317.000000
# 75%    100896.000000           1218.000000       5.000000     729.000000
# max    134528.000000          10625.000000    7570.000000   10630.000000
#
#        NewCreditCustomer  VerificationType            Age         Gender  \
# count      134529.000000     134484.000000  134529.000000  134484.000000
# mean            0.578373          2.817257      40.819295       0.442097
# std             0.493821          1.407908      12.348693       0.636083
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BidsPortfolioManager', 'BidsApi', 'BidsManual',
#        'NewCreditCustomer', 'VerificationType', 'LanguageCode', 'Age',
#        'Gender', 'Country', 'AppliedAmount', 'Amount', 'Interest',
#        'LoanDuration', 'MonthlyPayment', 'County', 'City', 'UseOfLoan',
#        'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'IncomeTotal', 'ExistingLiabilities',
#        'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash',
#        'MonthlyPaymentDay', 'Rating', 'Restructured', 'CreditScoreEsMicroL',
#        'PrincipalPaymentsMade', 'InterestAndPenaltyPaymentsMade',
#        'PrincipalBalance', 'InterestAndPenaltyBalance',
#        'NoOfPreviousLoansBeforeLoan', 'AmountOfPreviousLoansBeforeLoan',
#        'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan', 'Target'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Unnamed: 0                                134529
# BidsPortfolioManager                        5730
# BidsApi                                     1002
# BidsManual                                  4308
# NewCreditCustomer                              2
# VerificationType                               5
# LanguageCode                                   8
# Age                                           62
# Gender                                         3
# Country                                        4
# AppliedAmount                                593
# Amount                                      5223
# Interest                                    6501
# LoanDuration                                  31
# MonthlyPayment                             25281
# County                                      1010
# City                                        7733
# UseOfLoan                                     17
# Education                                      6
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                    0
# BidsPortfolioManager                          0
# BidsApi                                       0
# BidsManual                                    0
# NewCreditCustomer                             0
# VerificationType                             45
# LanguageCode                                  0
# Age                                           0
# Gender                                       45
# Country                                       0
# AppliedAmount                                 0
# Amount                                        0
# Interest                                      0
# LoanDuration                                  0
# MonthlyPayment                             6685
# County                                    36840
# City                                       9794
# UseOfLoan                                     0
# Education                                    45
# MaritalStatus                                45
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134529 entries, 0 to 134528
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Unnamed: 0                              134529 non-null  int64
#  1   BidsPortfolioManager                    134529 non-null  int64
#  2   BidsApi                                 134529 non-null  int64
#  3   BidsManual                              134529 non-null  float64
#  4   NewCreditCustomer                       134529 non-null  int64
#  5   VerificationType                        134484 non-null  float64
#  6   LanguageCode                            134529 non-null  object
#  7   Age                                     134529 non-null  int64
#  8   Gender                                  134484 non-null  float64
#  9   Country                                 134529 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Datatypes

df.dtypes
# Out:
# Unnamed: 0                                  int64
# BidsPortfolioManager                        int64
# BidsApi                                     int64
# BidsManual                                float64
# NewCreditCustomer                           int64
# VerificationType                          float64
# LanguageCode                               object
# Age                                         int64
# Gender                                    float64
# Country                                    object
# AppliedAmount                             float64
# Amount                                    float64
# Interest                                  float64
# LoanDuration                                int64
# MonthlyPayment                            float64
# County                                     object
# City                                       object
# UseOfLoan                                  object
# Education                                  object
# ...

# %%
df['City'].value_counts()
# Out:
# Tallinn                       15604
# TALLINN                        6146
# Tartu linn                     3326
# HELSINKI                       3294
# Pärnu linn                     1986
#                               ...
# KOSE VALD, ARDU                   1
# KALAMAJA                          1
# LLERENA                           1
# SALME VALD, TEHUMARDI KÜLA        1
# VEĽKÉ DRŽKOVCE                    1
# Name: City, Length: 7733, dtype: int64

# %% [markdown]
# # missing values

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df.fillna(0)
# Out:
#         Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  \
# 0                0                     0        0    115.0410
# 1                1                     0        0    140.6057
# 2                2                     0        0    319.5580
# 3                3                     0        0     57.5205
# 4                4                     0        0    319.5582
# ...            ...                   ...      ...         ...
# 134524      134524                  2515        0    485.0000
# 134525      134525                  1880        0   1120.0000
# 134526      134526                  1975        0    525.0000
# 134527      134527                  1840        0   1160.0000
# 134528      134528                  2990        0     10.0000
#
#         NewCreditCustomer  VerificationType LanguageCode  Age  Gender Country  \
# 0                       1               2.0            1   61     1.0      EE
# ...

# %%
df.fillna(0)
# Out:
#         Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  \
# 0                0                     0        0    115.0410
# 1                1                     0        0    140.6057
# 2                2                     0        0    319.5580
# 3                3                     0        0     57.5205
# 4                4                     0        0    319.5582
# ...            ...                   ...      ...         ...
# 134524      134524                  2515        0    485.0000
# 134525      134525                  1880        0   1120.0000
# 134526      134526                  1975        0    525.0000
# 134527      134527                  1840        0   1160.0000
# 134528      134528                  2990        0     10.0000
#
#         NewCreditCustomer  VerificationType LanguageCode  Age  Gender Country  \
# 0                       1               2.0            1   61     1.0      EE
# ...

# %% [markdown]
# # Correlation map

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <ipython-input-72-fb7a10d92579>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Blues')
# <Axes: >

# %% [markdown]
# # Heat map

# %%
#Heat map pearson correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(corrmat, vmax=.8, square=True);
# Out:
# <ipython-input-73-ccf8802efc0c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %% [markdown]
# # Scatter plot-AGE

# %%
plt.figure(figsize=(7,7))
plt.scatter(x='Age',y='Target',data=df)
plt.xlabel('Age')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# # Histogram

# %% [markdown]
# AGE

# %%
sns.histplot(df.Age,bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Box plot of Emplyee status

# %% [markdown]
# EMPLOYMENTSTATUS

# %%
sns.boxplot(x='EmploymentStatus',y='Target',data=df)
# Out:
# <Axes: xlabel='EmploymentStatus', ylabel='Target'>

# %% [markdown]
# PIE CHART

# %%
df['EmploymentStatus'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %% [markdown]
# EDUCATION BOXPLOT

# %%
sns.boxplot(x='Target',y='Education',data=df)
# Out:
# <Axes: xlabel='Target', ylabel='Education'>

# %% [markdown]
# EDUCATION COUNTPLOT

# %%
sns.countplot(data=df,x='Education', hue='Target',palette='bright')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %% [markdown]
# # Box plot interest

# %%
sns.set(style='whitegrid')
ax=sns.boxplot(x=df.Interest,showfliers=False)

# %% [markdown]
# BIDSMANUAL

# %%
sns.set(style='whitegrid')
ax=sns.boxplot(x=df.BidsManual,showfliers=False,color='green')

# %% [markdown]
# LINE PLOT LOANDURATION

# %%
#line plot
sns.lineplot(x='LoanDuration',y='Target', data=df )
# Out:
# <Axes: xlabel='LoanDuration', ylabel='Target'>

# %%
df['LoanDuration'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0           0                     0        0    115.0410                  1
# 1           1                     0        0    140.6057                  0
# 2           2                     0        0    319.5580                  1
# 3           3                     0        0     57.5205                  1
# 4           4                     0        0    319.5582                  1
#
#    VerificationType LanguageCode  Age  Gender Country  AppliedAmount  \
# 0               2.0            1   61     1.0      EE       319.5582
# 1               2.0            1   48     1.0      EE       191.7349
# 2               2.0            1   58     1.0      EE       319.5582
# 3               2.0            1   23     1.0      EE       127.8233
# 4               2.0            1   25     1.0      EE       319.5582
#
#      Amount  Interest  LoanDuration  MonthlyPayment    County          City  \
# ...

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#         BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0                          0        0    115.0410                  1
# 1                          0        0    140.6057                  0
# 2                          0        0    319.5580                  1
# 3                          0        0     57.5205                  1
# 4                          0        0    319.5582                  1
# ...                      ...      ...         ...                ...
# 134524                  2515        0    485.0000                  1
# 134525                  1880        0   1120.0000                  0
# 134526                  1975        0    525.0000                  1
# 134527                  1840        0   1160.0000                  0
# 134528                  2990        0     10.0000                  0
#
#         VerificationType LanguageCode  Age  Gender Country  AppliedAmount  \
# ...

# %% [markdown]
# # country countplot

# %%
sns.countplot(x=df["Country"],palette='BuGn_r')
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %% [markdown]
# # Loan duration count plot

# %%
plt.figure(figsize=(9,9))
sns.countplot(x=df["LoanDuration"],palette='Paired')
# Out:
# <Axes: xlabel='LoanDuration', ylabel='count'>

# %% [markdown]
# # MonthlyPaymentDay box plot

# %%
plt.figure(figsize=(8,8))
sns.boxplot(data=df, x="MonthlyPaymentDay", y="Target")
# Out:
# <Axes: xlabel='MonthlyPaymentDay', ylabel='Target'>

# %%
plt.figure(figsize=(8,8))
df['MonthlyPaymentDay'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %% [markdown]
# USE OF LOAN

# %%
#line plot
plt.figure(figsize=(8,8))
sns.lineplot(x='UseOfLoan',y='Target', data=df )
# Out:
# <Axes: xlabel='UseOfLoan', ylabel='Target'>

# %%
plt.figure(figsize=(8,8))
df['UseOfLoan'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Interest bar plot

# %%
sns.histplot(df.Interest,bins=10,color='blue')
# Out:
# <Axes: xlabel='Interest', ylabel='Count'>

# %% [markdown]
# VERIFICATION TYPE

# %%
sns.countplot(x=df["VerificationType"],palette='Set2')
# Out:
# <Axes: xlabel='VerificationType', ylabel='count'>

# %%
sns.countplot(data=df, y="VerificationType", hue="Target")
# Out:
# <Axes: xlabel='count', ylabel='VerificationType'>

# %% [markdown]
# # Language code bar chat

# %%
sns.histplot(df.LanguageCode	,bins=10,color='green')
# Out:
# <Axes: xlabel='LanguageCode', ylabel='Count'>

# %% [markdown]
# LANGUAGE CODE

# %%
LanguageCode_group = df.groupby('LanguageCode')['Target'].value_counts().unstack().fillna(0)
LanguageCode_group.plot(kind='bar', stacked=True)
plt.xlabel('LanguageCode')
plt.ylabel('Target')
plt.title('Languagecode vs Status')
plt.legend(title='Target', loc='upper right', labels=['0', '1'])
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0  BidsPortfolioManager  BidsApi  BidsManual  NewCreditCustomer  \
# 0           0                     0        0    115.0410                  1
# 1           1                     0        0    140.6057                  0
# 2           2                     0        0    319.5580                  1
# 3           3                     0        0     57.5205                  1
# 4           4                     0        0    319.5582                  1
#
#    VerificationType LanguageCode  Age  Gender Country  AppliedAmount  \
# 0               2.0            1   61     1.0      EE       319.5582
# 1               2.0            1   48     1.0      EE       191.7349
# 2               2.0            1   58     1.0      EE       319.5582
# 3               2.0            1   23     1.0      EE       127.8233
# 4               2.0            1   25     1.0      EE       319.5582
#
#      Amount  Interest  LoanDuration  MonthlyPayment    County          City  \
# ...

# %% [markdown]
# # Appliedamout plot

# %%
sns.histplot(df.AppliedAmount	,bins=10,color='orange')
# Out:
# <Axes: xlabel='AppliedAmount', ylabel='Count'>

# %% [markdown]
# # NoOfPreviousLoansBeforeLoan plot

# %%
sns.countplot(x=df["NoOfPreviousLoansBeforeLoan"],palette='muted')
# Out:
# <Axes: xlabel='NoOfPreviousLoansBeforeLoan', ylabel='count'>

# %% [markdown]
# NoOfPreviousLoansBeforeLoa

# %%
#line plot
plt.figure(figsize=(8,8))
sns.lineplot(x='NoOfPreviousLoansBeforeLoan',y='Target', data=df )
# Out:
# <Axes: xlabel='NoOfPreviousLoansBeforeLoan', ylabel='Target'>

# %% [markdown]
# EmploymentDurationCurrentEmployer countplot

# %%
plt.figure(figsize=(12,12))
sns.countplot(x=df["EmploymentDurationCurrentEmployer"],palette='colorblind')
# Out:
# <Axes: xlabel='EmploymentDurationCurrentEmployer', ylabel='count'>

# %% [markdown]
# OCCUPATION AREA

# %%
plt.figure(figsize=(10,10))
sns.violinplot(data=df, x="OccupationArea", y="Target")
# Out:
# <Axes: xlabel='OccupationArea', ylabel='Target'>

# %%
OccupationArea_group = df.groupby('OccupationArea')['Target'].value_counts().unstack().fillna(0)
OccupationArea_group.plot(kind='bar', stacked=True)
plt.xlabel('OccupationArea')
plt.ylabel('Target')
plt.title('OccupationArea vs Status')
plt.legend(title='Target', loc='upper right', labels=['0', '1'])
plt.show()

# %% [markdown]
# RESTRUCTURED COUNTPLOT

# %%
sns.countplot(data=df,x='Restructured', hue='Target',palette='pastel')
# Out:
# <Axes: xlabel='Restructured', ylabel='count'>

# %% [markdown]
# OCUUPATION AREA COUNTPLOT

# %%
plt.figure(figsize=(9,12))
sns.countplot(x=df["OccupationArea"],palette='bright')
# Out:
# <Axes: xlabel='OccupationArea', ylabel='count'>

# %% [markdown]
# MARRIAL STATUS COUNTPLOT

# %%
sns.countplot(x=df["MaritalStatus"],palette='dark')
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# GENDER VOILON PLOT

# %%
sns.violinplot(data=df, x="Gender", y="Target")
# Out:
# <Axes: xlabel='Gender', ylabel='Target'>

# %% [markdown]
# GENDER COUNTPLOT

# %%
# Count of Gender of the defaulters
sns.countplot(x = df['Target'], hue =df['Gender'], palette='bright')
# Out:
# <Axes: xlabel='Target', ylabel='count'>

# %% [markdown]
# RATING BAR PLOT

# %%
Rating_counts = df['Rating'].value_counts()

plt.figure(figsize=(10, 3))
sns.barplot(x=Rating_counts.index, y=Rating_counts.values)
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(10, 3))
sns.countplot(x='Rating', hue='Target', data=df)
plt.title("Distribution of Rating across Default Classes")
plt.xlabel("Rating")
plt.ylabel("Count")

plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BidsPortfolioManager', 'BidsApi', 'BidsManual',
#        'NewCreditCustomer', 'VerificationType', 'LanguageCode', 'Age',
#        'Gender', 'Country', 'AppliedAmount', 'Amount', 'Interest',
#        'LoanDuration', 'MonthlyPayment', 'County', 'City', 'UseOfLoan',
#        'Education', 'MaritalStatus', 'EmploymentStatus',
#        'EmploymentDurationCurrentEmployer', 'OccupationArea',
#        'HomeOwnershipType', 'IncomeTotal', 'ExistingLiabilities',
#        'LiabilitiesTotal', 'RefinanceLiabilities', 'DebtToIncome', 'FreeCash',
#        'MonthlyPaymentDay', 'Rating', 'Restructured', 'CreditScoreEsMicroL',
#        'PrincipalPaymentsMade', 'InterestAndPenaltyPaymentsMade',
#        'PrincipalBalance', 'InterestAndPenaltyBalance',
#        'NoOfPreviousLoansBeforeLoan', 'AmountOfPreviousLoansBeforeLoan',
#        'PreviousRepaymentsBeforeLoan',
#        'PreviousEarlyRepaymentsCountBeforeLoan', 'Target'],
#       dtype='object')

# %% [markdown]
# NEW CREDIT CUSTOMER COUNT PLOT

# %%
sns.countplot(data=df, x="NewCreditCustomer", hue="Target",palette='bright')
# Out:
# <Axes: xlabel='NewCreditCustomer', ylabel='count'>

# %% [markdown]
# HIST PLOT AMOUNT

# %%
plt.figure(figsize=(6,6))
sns.histplot(df['Amount'], kde=True);

# %% [markdown]
# PRINCPAL BALANCE HIST PLOT

# %%
sns.histplot(df.PrincipalBalance	,bins=10,color='orange')
# Out:
# <Axes: xlabel='PrincipalBalance', ylabel='Count'>

# %% [markdown]
# PRINCIPAL PAYMENT MADE HIST PLOT

# %%
sns.histplot(df.PrincipalPaymentsMade	,bins=10,color='red')
# Out:
# <Axes: xlabel='PrincipalPaymentsMade', ylabel='Count'>

# %% [markdown]
# AMOUNT OF PREVIOUS BEFORE LOAN HIST PLOT

# %%
plt.figure(figsize=(6,6))
sns.histplot(df['AmountOfPreviousLoansBeforeLoan'], kde=True);

# %% [markdown]
# PAIPLOTS

# %% [markdown]
# DEBT TO INCOME -INTEREST AND PENALTY BALANE-PREVIOUS EARLY PAYMENT== PAIRPLOT

# %%
g=sns.pairplot(data=df,vars=['DebtToIncome','InterestAndPenaltyBalance','PreviousEarlyRepaymentsCountBeforeLoan'],hue='Target',palette='husl')

# %% [markdown]
# AMOUNT -PRINCPAL BALANCE-INTEREST-PRINCPAL PAYEMENT MADS PAIRPLOT

# %%
g=sns.pairplot(data=df,vars=['Amount','PrincipalBalance','Interest','PrincipalPaymentsMade'],markers=['o','s'],hue='Target',palette='husl')
